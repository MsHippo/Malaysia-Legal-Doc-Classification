# %%
from sklearn import svm
import sklearn.model_selection as model_selection
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
import sklearn.datasets as skd
import os

# %% [markdown]
# ## Load Data & Lower case

# %%
training_files_path = 'C:/Users/heihe/Desktop/Malaysia-Legal-Doc-Classification/classification_nlp/training_data_txt'
testing_files_path = 'C:/Users/heihe/Desktop/Malaysia-Legal-Doc-Classification/classification_nlp/testing_data_txt'

# %%
for root, dirs, files in os.walk(training_files_path):
    for file in files:
        with open( file.endswith(".txt"), 'r') as fileinput:
            for line in fileinput:
                line = line.lower()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_49044/1004955345.py in <module>
#       1 for root, dirs, files in os.walk(training_files_path):
#       2     for file in files:
# ----> 3         with open( file.endswith(".txt"), 'r') as fileinput:
#       4             for line in fileinput:
#       5                 line = line.lower()
#
# ValueError: Cannot open console output buffer for reading

# %%
def lower_case(file_path):
    for root, dirs, files in os.walk(file_path):
        for file in files:
            with open( file.endswith(".file"), 'r') as fileinput:
                for line in fileinput:
                    line = line.lower()

# %%
legal_train = skd.load_files(lower_case(training_files_path), categories= categories_list(training_files_path), encoding= 'ISO-8859-1')
legal_test = skd.load_files(lower_case(testing_files_path), categories= categories_list(training_files_path), encoding= 'ISO-8859-1')
print ('data loaded')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_49044/2852984456.py in <module>
# ----> 1 legal_train = skd.load_files(lower_case(training_files_path), categories= categories_list(training_files_path), encoding= 'ISO-8859-1')
#       2 legal_test = skd.load_files(lower_case(testing_files_path), categories= categories_list(training_files_path), encoding= 'ISO-8859-1')
#       3 print ('data loaded')
#
# ~\AppData\Local\Temp/ipykernel_49044/3440691444.py in lower_case(file_path)
#       2     for root, dirs, files in os.walk(file_path):
#       3         for file in files:
# ----> 4             with open( file.endswith(".file"), 'r') as fileinput:
#       5                 for line in fileinput:
#       6                     line = line.lower()
#
# ValueError: Cannot open console output buffer for reading

# %% [markdown]
# # Tokenization

# %%
legal_train = word_tokenize(entry) for entry in legal_train
legal_test = word_tokenize(entry) for entry in legal_test

# %% [markdown]
# # Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting

# %%
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

# %%
rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(legal_train.data, legal_train.target)
poly = svm.SVC(kernel='poly', degree=3, C=1).fit(legal_train.data, legal_train.target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_49044/3150433590.py in <module>
# ----> 1 rbf = svm.SVC(kernel='rbf', gamma=0.5, C=0.1).fit(legal_train.data, legal_train.target)
#       2 poly = svm.SVC(kernel='poly', degree=3, C=1).fit(legal_train.data, legal_train.target)
#
# ~\anaconda3\envs\MyDocClass\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     167             check_consistent_length(X, y)
#     168         else:
# --> 169             X, y = self._validate_data(X, y, dtype=np.float64,
#     170                                        order='C', accept_sparse='csr',
#     171                                        accept_large_sparse=False)
#
# ~\anaconda3\envs\MyDocClass\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
poly_pred = poly.predict(legal_test.data)
rbf_pred = rbf.predict(legal_test.data)

# %%
poly_accuracy = accuracy_score(legal_test.target, poly_pred)
poly_f1 = f1_score(y_test, poly_pred, average='weighted')
print('Accuracy (Polynomial Kernel): ', "%.2f" % (poly_accuracy*100))
print('F1 (Polynomial Kernel): ', "%.2f" % (poly_f1*100))

# %%
rbf_accuracy = accuracy_score(legal_test.target, rbf_pred)
rbf_f1 = f1_score(y_test, rbf_pred, average='weighted')
print('Accuracy (RBF Kernel): ', "%.2f" % (rbf_accuracy*100))
print('F1 (RBF Kernel): ', "%.2f" % (rbf_f1*100))
